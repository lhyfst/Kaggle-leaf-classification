# %%
# %matplotlib inline
import numpy as np
from shape_and_blade_augment import augment_display,wrapper_augment_a_shape_and_blade_data

# %%
shape_contour_array = np.load('../middata/shape_contour_array.npy')
blade_contour_array = np.load('../middata/blade_contour_array.npy')

# %%
augment_display(1,shape_contour_array, blade_contour_array)
