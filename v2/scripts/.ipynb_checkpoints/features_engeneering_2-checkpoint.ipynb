# %%
from features_extraction import extract_features,generate_features_list,plot_leaf_and_features

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from tqdm import tqdm_notebook as tqdm

# %%
def read_img(img_no):
    """reads image from disk"""
    return mpimg.imread('../rawdata/images/' + str(img_no) + '.jpg')

# %%
tmp = read_img(1)

# %%
tmp.shape
# Out:
# (467, 526)

# %%
max_x = 0
max_y = 0
for idx in tqdm(range(1584)):
    idx = idx+1
    tmp = read_img(idx)
    if tmp.shape[0] > max_x:
        max_x = tmp.shape[0]
    if tmp.shape[1] > max_y:
        max_y = tmp.shape[1]
        
print max_x
print max_y
# Out:
# HBox(children=(IntProgress(value=0, max=1584), HTML(value=u'')))
# 1089
# 1706

# %%
x_list = []
y_list = []
for idx in tqdm(range(1584)):
    idx = idx+1
    tmp = read_img(idx)
    x_list.append(tmp.shape[0])
    y_list.append(tmp.shape[1])
# Out:
# HBox(children=(IntProgress(value=0, max=1584), HTML(value=u'')))

# %%
# %pylab
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
print mean(x_list)
# Out:
# 493.11237373737373

# %%
tmp.size
# Out:
# 245642

# %%
tmp_features_list,tmp_nums_list = generate_features_list([1,2,3],True)
# Out:
# 1
# 2
# 3

# %%
features = tmp_features_list[0]

# %%
tmp_features_list[0]['img_num']
# Out:
# 1

# %%
tmp_features_list[1]['blade_img'].shape
# Out:
# (667, 251)

# %%
plt.plot(*features['blade_series'])
plt.show()

# %%
plt.plot(features['blade_series'][0])
plt.show()

# %%
# features['shape_contour']
plt.plot(features['shape_contour'][:,1])
plt.show()

# %%
# features['shape_contour']
plt.plot(features['shape_contour'][:,0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5ec7076bf094> in <module>()
#       1 # features['shape_contour']
# ----> 2 plt.plot(features['shape_contour'][:,0])
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plot_leaf_and_features(features[0])
